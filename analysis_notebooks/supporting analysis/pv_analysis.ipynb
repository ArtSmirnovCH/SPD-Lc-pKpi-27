# %% [markdown]
# # Distributions before PV re-fit

# %% [markdown]
# ## Prepare Env & Import Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import sys
import os
import io
from contextlib import redirect_stdout, redirect_stderr


try:
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    current_dir = os.getcwd()

parent_dir = os.path.join(current_dir, '..', '..')
sys.path.insert(0, parent_dir)


from analysis_scripts.draw_scripts import hist_plot
from analysis_scripts.fit_scripts import fit_distr_double_gauss


df = pd.read_csv('/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/Data/ana_PV_27_var_1.csv')

# %% [markdown]
# ## max_chi2 distribution

# %%
fig, ax = plt.subplots(figsize=(5, 5))

# max_chi2 -- maximum chi2 of track in vertex when the re-fit procedure stops.

hist_plot(
    data=df[(df['max_chi2_cut'] == 30.0) & (df['max_chi2_observed'] < 50.0)],
    distr_name='max_chi2_observed',
    ax=ax,
    bins=40
)

# plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/max_chi2_default.pdf', bbox_inches='tight')

# %%
PV_diff_x = df.loc[df['max_chi2_cut'] == 30.0, 'PV_diff_x']
PV_diff_y = df.loc[df['max_chi2_cut'] == 30.0, 'PV_diff_y']
PV_diff_z = df.loc[df['max_chi2_cut'] == 30.0, 'PV_diff_z']


# zeroth approximation
print(f'x-projection PV resolution [cm]: {PV_diff_x[abs(PV_diff_x) < 0.03].std() * 1e4}')
print(f'y-projection PV resolution [cm]: {PV_diff_y[abs(PV_diff_x) < 0.03].std() * 1e4}')
print(f'z-projection PV resolution [cm]: {PV_diff_z[abs(PV_diff_x) < 0.03].std() * 1e4}')
# Out:
# x-projection PV resolution [cm]: 76.2155176913066
# y-projection PV resolution [cm]: 97.54666463092002
# z-projection PV resolution [cm]: 125.18729113129375

# %% [markdown]
# ### x-projection

# %%
distr_name = 'PV_diff_x'
sig_PV_df_sel = PV_diff_x[abs(PV_diff_x) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (x projection)',
    x_label='PV resolution (x projection) [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/{distr_name}_no_refit.pdf', bbox_inches='tight')
plt.show()
# Out:
# Method: Nelder-Mead
# ****************************************************************************************************
# New best method: Nelder-Mead, success: True
# ****************************************************************************************************
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='Powell'
# ============================================================
# Optimization result:
# Success: True
# Message: Optimization terminated successfully.
# Number of iterations: 16
# Final objective value: 50.095120
# Chi-squared: 50.10
# Reduced chi-squared: 1.518
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 593.4674 +- 54.8566
#          mu = -0.000125 +- 0.000112
#          sigma = 0.009005 +- 0.000326
# Gauss 2: A = 1614.2588 +- 52.3403
#          mu = 0.000005 +- 0.000055
#          sigma = 0.004000 +- 0.000110
# Constant: C = 25.6607 +- 2.7934
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: -0.000030 +- 0.000050
# Effective Sigma: 0.005788 +- 0.000183
# ============================================================

# %% [markdown]
# ### y-projection

# %%
distr_name = 'PV_diff_y'
sig_PV_df_sel = PV_diff_y[abs(PV_diff_y) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (y projection)',
    x_label='PV resolution (y projection) [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/{distr_name}_no_refit.pdf', bbox_inches='tight')
plt.show()
# Out:
# Method: Nelder-Mead
# ****************************************************************************************************
# New best method: Nelder-Mead, success: True
# ****************************************************************************************************
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# ****************************************************************************************************
# New best method: trust-constr, success: True
# ****************************************************************************************************
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='trust-constr'
# ============================================================
# Optimization result:
# Success: True
# Message: `xtol` termination condition is satisfied.
# Number of iterations: 369
# Final objective value: 33.531555
# Chi-squared: 33.53
# Reduced chi-squared: 1.016
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 571.2304 +- 39.1160
#          mu = -0.000108 +- 0.000095
#          sigma = 0.009089 +- 0.000248
# Gauss 2: A = 1627.8415 +- 38.7304
#          mu = -0.000032 +- 0.000045
#          sigma = 0.004059 +- 0.000079
# Constant: C = 25.2753 +- 2.2442
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: -0.000052 +- 0.000041
# Effective Sigma: 0.005801 +- 0.000135
# ============================================================

# %% [markdown]
# ### z-projection

# %%
from analysis_scripts.fit_scripts import fit_distr_double_gauss


distr_name = 'PV_diff_z'
sig_PV_df_sel = PV_diff_z[abs(PV_diff_z) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (z projection)',
    x_label='PV resolution (z projection) [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/{distr_name}_no_refit.pdf', bbox_inches='tight')
plt.show()
# Out:
# Method: Nelder-Mead
# ****************************************************************************************************
# New best method: Nelder-Mead, success: True
# ****************************************************************************************************
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# ****************************************************************************************************
# New best method: trust-constr, success: True
# ****************************************************************************************************
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='trust-constr'
# ============================================================
# Optimization result:
# Success: True
# Message: `xtol` termination condition is satisfied.
# Number of iterations: 315
# Final objective value: 36.509320
# Chi-squared: 36.51
# Reduced chi-squared: 1.106
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 583.6622 +- 41.4819
#          mu = -0.000266 +- 0.000105
#          sigma = 0.009785 +- 0.000307
# Gauss 2: A = 1348.8175 +- 41.2601
#          mu = 0.000132 +- 0.000056
#          sigma = 0.004331 +- 0.000106
# Constant: C = 29.5456 +- 3.3018
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: 0.000011 +- 0.000051
# Effective Sigma: 0.006481 +- 0.000177
# ============================================================

# %% [markdown]
# # Distributions after PV re-fit (Var-1)

# %% [markdown]
# ## Prepare Env & Import Data

# %%
df = pd.read_csv('/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/Data/ana_PV_27_var_1.csv')

# %% [markdown]
# ## max_chi2 distribution

# %%
from analysis_scripts.draw_scripts import hist_plot


fig, ax = plt.subplots(figsize=(5, 5))

hist_plot(
    data=df[(df['max_chi2_cut'] == 30.0) & (df['max_chi2_observed'] < 50.0)],
    distr_name='max_chi2_observed',
    ax=ax,
    bins=40
)

# %% [markdown]
# ## zeroth approximation

# %%
res_x = []
res_y = []
res_z = []
list_mean_number_removed_tracks = []

cuts = sorted(df['max_chi2_cut'].unique(), reverse=True)

for cut in cuts:

    PV_diff_x = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_x']
    PV_diff_y = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_y']
    PV_diff_z = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_z']

    print(f'\n{'='*50}\nCut value: {cut}\n{'='*50}')

    res_x_val = PV_diff_x[abs(PV_diff_x) < 0.03].std() * 1e4
    res_y_val = PV_diff_y[abs(PV_diff_y) < 0.03].std() * 1e4
    res_z_val = PV_diff_z[abs(PV_diff_z) < 0.03].std() * 1e4

    res_x.append(res_x_val)
    res_y.append(res_y_val)
    res_z.append(res_z_val)

    mean_number_removed_tracks = df.loc[df['max_chi2_cut'] == cut, 'num_removed_tracks'].mean()
    list_mean_number_removed_tracks.append(mean_number_removed_tracks)

    print(f'Mean number of removed tracks: {mean_number_removed_tracks}')
    print(f'x-projection PV resolution [cm]: {res_x_val}')
    print(f'y-projection PV resolution [cm]: {res_y_val}')
    print(f'z-projection PV resolution [cm]: {res_z_val}')

    
res_x = np.array(res_x)
res_y = np.array(res_y)
res_z = np.array(res_z)
list_mean_number_removed_tracks = np.array(list_mean_number_removed_tracks)

print(f'Best x at cut: {cuts[res_x.argmin()]}')
print(f'Best y at cut: {cuts[res_y.argmin()]}')
print(f'Best z at cut: {cuts[res_z.argmin()]}')

res_df = pd.DataFrame({
    'cut': cuts,
    'std_x [mkm]': res_x,
    'std_y [mkm]': res_y,
    'std_z [mkm]': res_z,
    'mean_rm_tracks': list_mean_number_removed_tracks
})

res_df_melted = res_df.melt(
    id_vars=['cut'], 
    value_vars=['std_x [mkm]', 'std_y [mkm]', 'std_z [mkm]', 'mean_rm_tracks'],
    var_name='col_type',
    value_name='col_value'
)

fig, ax = plt.subplots(figsize=(10, 4))
sns.lineplot(
    data=res_df_melted,
    x='cut',
    y='col_value',
    hue='col_type',
    ax=ax
)

ax.set_title("PV Resolution VS. max_chi2_cut")
ax.set_xlabel('Max. Chi2 cut value')
ax.set_ylabel('PV resolution (reco - MC).std()')
ax.grid(True, linestyle='--', alpha=0.7)
ax.legend(title='Legend:')

plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/re_fit_setup_chi2_cut.pdf', bbox_inches='tight')
plt.show()
# Out:
# ==================================================
# Cut value: 30.0
# ==================================================
# Mean number of removed tracks: 0.07870283461610662
# x-projection PV resolution [cm]: 71.29227248203492
# y-projection PV resolution [cm]: 71.02196049141884
# z-projection PV resolution [cm]: 79.85447634793825
#
# ==================================================
# Cut value: 12.0
# ==================================================
# Mean number of removed tracks: 0.1612539891120706
# x-projection PV resolution [cm]: 69.38876134624813
# y-projection PV resolution [cm]: 69.00269124641072
# z-projection PV resolution [cm]: 77.80652535593164
#
# ==================================================
# Cut value: 11.0
# ==================================================
# Mean number of removed tracks: 0.17486390088229772
# x-projection PV resolution [cm]: 69.17390539132916
# y-projection PV resolution [cm]: 68.84274775258532
# z-projection PV resolution [cm]: 77.63835643439738
#
# ==================================================
# Cut value: 10.0
# ==================================================
# Mean number of removed tracks: 0.18960015017833678
# x-projection PV resolution [cm]: 68.85200598562551
# y-projection PV resolution [cm]: 68.5746304010623
# z-projection PV resolution [cm]: 77.45893628992356
#
# ==================================================
# Cut value: 9.0
# ==================================================
# Mean number of removed tracks: 0.2093579876102872
# x-projection PV resolution [cm]: 68.67850679810003
# y-projection PV resolution [cm]: 68.12978610224108
# z-projection PV resolution [cm]: 77.2369690657624
#
# ==================================================
# Cut value: 8.0
# ==================================================
# Mean number of removed tracks: 0.23390275952693823
# x-projection PV resolution [cm]: 68.22641110874618
# y-projection PV resolution [cm]: 67.8213629642884
# z-projection PV resolution [cm]: 76.92248045352022
#
# ==================================================
# Cut value: 7.0
# ==================================================
# Mean number of removed tracks: 0.2662849633940304
# x-projection PV resolution [cm]: 67.97384267361124
# y-projection PV resolution [cm]: 67.56622953341503
# z-projection PV resolution [cm]: 76.67288008066281
#
# ==================================================
# Cut value: 6.0
# ==================================================
# Mean number of removed tracks: 0.3108222263938427
# x-projection PV resolution [cm]: 67.88525337087962
# y-projection PV resolution [cm]: 67.55568534089484
# z-projection PV resolution [cm]: 76.41665744510536
#
# ==================================================
# Cut value: 5.0
# ==================================================
# Mean number of removed tracks: 0.38018584569175895
# x-projection PV resolution [cm]: 67.86247521188707
# y-projection PV resolution [cm]: 67.36330304358
# z-projection PV resolution [cm]: 76.10101226621654
#
# ==================================================
# Cut value: 4.0
# ==================================================
# Mean number of removed tracks: 0.5030974281959827
# x-projection PV resolution [cm]: 67.93641541286803
# y-projection PV resolution [cm]: 67.56579320245129
# z-projection PV resolution [cm]: 75.86329967137017
#
# ==================================================
# Cut value: 3.0
# ==================================================
# Mean number of removed tracks: 0.7222170076966398
# x-projection PV resolution [cm]: 68.78163536839307
# y-projection PV resolution [cm]: 68.12999476852615
# z-projection PV resolution [cm]: 75.96190658113133
#
# ==================================================
# Cut value: 2.0
# ==================================================
# Mean number of removed tracks: 1.1828421250234653
# x-projection PV resolution [cm]: 70.75497184956332
# y-projection PV resolution [cm]: 70.39156410655946
# z-projection PV resolution [cm]: 76.71638182474823
# Best x at cut: 5.0
# Best y at cut: 5.0
# Best z at cut: 4.0

# %% [markdown]
# ## Cut properties

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20, 5))

hist_plot(
    data=df[df['max_chi2_cut'] == 5.0],
    distr_name='tracks_per_vertex',
    ax=axes[0],
    bins=40
)

hist_plot(
    data=df.loc[(df['max_chi2_cut'] == 5.0) & (df['num_removed_tracks'] < 7)],
    distr_name='num_removed_tracks',
    ax=axes[1],
    bins=40
)

hist_plot(
    data=df.loc[(df['max_chi2_cut'] == 5.0) & (df['chi2_PV'] < 40)],
    distr_name='chi2_PV',
    ax=axes[2],
    bins=40
)

hist_plot(
    data=df.loc[(df['max_chi2_cut'] == 5.0) & (df['chi2_per_ndf_PV'] < 4)],
    distr_name='chi2_per_ndf_PV',
    ax=axes[3],
    bins=40
)

plt.tight_layout()
plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/re_fit_after_cut_properties.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Resolutions

# %% [markdown]
# ### x-projection (cut = 5)

# %%
cut = 5.

distr_name = 'PV_diff_ES_x'
PV_diff_x = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_x']

sig_PV_df_sel = PV_diff_x[abs(PV_diff_x) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (x projection) Extra Selection',
    x_label='PV resolution (x projection) Extra Selection [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/{distr_name}_refit.pdf', bbox_inches='tight')
plt.show()
# Out:
# Method: Nelder-Mead
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='Powell'
# ============================================================
# Optimization result:
# Success: True
# Message: Optimization terminated successfully.
# Number of iterations: 31
# Final objective value: 57.755694
# Chi-squared: 57.76
# Reduced chi-squared: 1.750
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 572.7717 +- 56.4031
#          mu = -0.000157 +- 0.000116
#          sigma = 0.008608 +- 0.000297
# Gauss 2: A = 1854.9685 +- 53.6943
#          mu = 0.000010 +- 0.000052
#          sigma = 0.003921 +- 0.000098
# Constant: C = 13.4792 +- 2.0124
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: -0.000030 +- 0.000048
# Effective Sigma: 0.005407 +- 0.000160
# ============================================================

# %% [markdown]
# ### y-projection (cut = 5)

# %%
cut = 5.

distr_name = 'PV_diff_ES_y'
PV_diff_x = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_y']

sig_PV_df_sel = PV_diff_x[abs(PV_diff_x) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (y projection) Extra Selection',
    x_label='PV resolution (y projection) Extra Selection [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/{distr_name}_refit.pdf', bbox_inches='tight')
plt.show()
# Out:
# Method: Nelder-Mead
# ****************************************************************************************************
# New best method: Nelder-Mead, success: True
# ****************************************************************************************************
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# ****************************************************************************************************
# New best method: trust-constr, success: True
# ****************************************************************************************************
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='trust-constr'
# ============================================================
# Optimization result:
# Success: True
# Message: `xtol` termination condition is satisfied.
# Number of iterations: 417
# Final objective value: 26.027096
# Chi-squared: 26.03
# Reduced chi-squared: 0.789
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 624.3150 +- 36.7071
#          mu = -0.000088 +- 0.000073
#          sigma = 0.008329 +- 0.000168
# Gauss 2: A = 1759.8327 +- 35.9566
#          mu = -0.000016 +- 0.000037
#          sigma = 0.003868 +- 0.000063
# Constant: C = 14.6226 +- 1.3087
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: -0.000035 +- 0.000033
# Effective Sigma: 0.005405 +- 0.000097
# ============================================================

# %% [markdown]
# ### z-projection (cut = 5)

# %%
cut = 5.

distr_name = 'PV_diff_ES_z'
PV_diff_x = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_z']

sig_PV_df_sel = PV_diff_x[abs(PV_diff_x) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (z projection) Extra Selection',
    x_label='PV resolution (z projection) Extra Selection [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

plt.savefig(f'/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/plots/{distr_name}_refit.pdf', bbox_inches='tight')
plt.show()
# Out:
# Method: Nelder-Mead
# ****************************************************************************************************
# New best method: Nelder-Mead, success: True
# ****************************************************************************************************
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='Powell'
# ============================================================
# Optimization result:
# Success: True
# Message: Optimization terminated successfully.
# Number of iterations: 20
# Final objective value: 32.105752
# Chi-squared: 32.11
# Reduced chi-squared: 0.973
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 616.1071 +- 49.5398
#          mu = -0.000166 +- 0.000092
#          sigma = 0.008944 +- 0.000259
# Gauss 2: A = 1504.7397 +- 47.3981
#          mu = 0.000063 +- 0.000049
#          sigma = 0.004215 +- 0.000100
# Constant: C = 23.4488 +- 2.1480
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: -0.000004 +- 0.000044
# Effective Sigma: 0.005987 +- 0.000154
# ============================================================

# %% [markdown]
# # Distributions after PV re-fit (Var-2)

# %% [markdown]
# ## Prepare Env & Import Data

# %%
df = pd.read_csv('/home/ome123/Рабочий стол/SPD/SPD_Lc_pKpi_27/Data/ana_PV_27_var_2.csv')

# %% [markdown]
# ## max_chi2 distribution

# %%
from analysis_scripts.draw_scripts import hist_plot


distr_name = 'max_chi2_observed'

fig, ax = plt.subplots(figsize=(5, 5))

hist_plot(
    data=df[(df['max_chi2_cut'] == 30.0) & (df['max_chi2_observed'] < 50.0)],
    distr_name=distr_name,
    ax=ax,
    bins=40
)

# %% [markdown]
# ## zeroth approximation

# %%
res_x = []
res_y = []
res_z = []

cuts = sorted(df['max_chi2_cut'].unique(), reverse=True)

for cut in cuts:

    PV_diff_x = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_x']
    PV_diff_y = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_y']
    PV_diff_z = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_z']

    print(f'\n{'='*50}\nCut value: {cut}\n{'='*50}')

    res_x_val = PV_diff_x[abs(PV_diff_x) < 0.03].std() * 1e4
    res_y_val = PV_diff_y[abs(PV_diff_y) < 0.03].std() * 1e4
    res_z_val = PV_diff_z[abs(PV_diff_z) < 0.03].std() * 1e4

    res_x.append(res_x_val)
    res_y.append(res_y_val)
    res_z.append(res_z_val)

    print(f'Mean number of removed tracks: {df.loc[df['max_chi2_cut'] == cut, 'num_removed_tracks'].mean()}')
    print(f'x-projection PV resolution [cm]: {res_x_val}')
    print(f'y-projection PV resolution [cm]: {res_y_val}')
    print(f'z-projection PV resolution [cm]: {res_z_val}')
    
res_x = np.array(res_x)
res_y = np.array(res_y)
res_z = np.array(res_z)

print(f'Best x at cut: {cuts[res_x.argmin()]}')
print(f'Best y at cut: {cuts[res_y.argmin()]}')
print(f'Best z at cut: {cuts[res_z.argmin()]}')
# Out:
# ==================================================
# Cut value: 30.0
# ==================================================
# Mean number of removed tracks: 0.08070043659922069
# x-projection PV resolution [cm]: 73.30686184646147
# y-projection PV resolution [cm]: 73.1311732894916
# z-projection PV resolution [cm]: 83.31001808255598
#
# ==================================================
# Cut value: 12.0
# ==================================================
# Mean number of removed tracks: 0.1707901037509976
# x-projection PV resolution [cm]: 71.32735203265861
# y-projection PV resolution [cm]: 71.4758181776582
# z-projection PV resolution [cm]: 82.1148024536945
#
# ==================================================
# Cut value: 11.0
# ==================================================
# Mean number of removed tracks: 0.18341861884418573
# x-projection PV resolution [cm]: 71.08023957099782
# y-projection PV resolution [cm]: 71.43779502260011
# z-projection PV resolution [cm]: 82.0585925041709
#
# ==================================================
# Cut value: 10.0
# ==================================================
# Mean number of removed tracks: 0.20027228768602412
# x-projection PV resolution [cm]: 70.90805510747144
# y-projection PV resolution [cm]: 71.25702343278739
# z-projection PV resolution [cm]: 81.93479997327337
#
# ==================================================
# Cut value: 9.0
# ==================================================
# Mean number of removed tracks: 0.2207408102905967
# x-projection PV resolution [cm]: 70.7708100524849
# y-projection PV resolution [cm]: 71.1588320661137
# z-projection PV resolution [cm]: 81.70391710342203
#
# ==================================================
# Cut value: 8.0
# ==================================================
# Mean number of removed tracks: 0.2477348481291958
# x-projection PV resolution [cm]: 70.45062987180688
# y-projection PV resolution [cm]: 71.01445209120753
# z-projection PV resolution [cm]: 81.5699400630001
#
# ==================================================
# Cut value: 7.0
# ==================================================
# Mean number of removed tracks: 0.2823341627153655
# x-projection PV resolution [cm]: 70.36064639302239
# y-projection PV resolution [cm]: 70.66225222261572
# z-projection PV resolution [cm]: 81.45096773706764
#
# ==================================================
# Cut value: 6.0
# ==================================================
# Mean number of removed tracks: 0.33402187690718743
# x-projection PV resolution [cm]: 70.18991349065537
# y-projection PV resolution [cm]: 70.76714938462753
# z-projection PV resolution [cm]: 81.37817624846204
#
# ==================================================
# Cut value: 5.0
# ==================================================
# Mean number of removed tracks: 0.4150509365757476
# x-projection PV resolution [cm]: 70.06796319340111
# y-projection PV resolution [cm]: 70.8434585352769
# z-projection PV resolution [cm]: 81.1539490530025
#
# ==================================================
# Cut value: 4.0
# ==================================================
# Mean number of removed tracks: 0.5475329796723158
# x-projection PV resolution [cm]: 70.74138717265895
# y-projection PV resolution [cm]: 71.26350017986314
# z-projection PV resolution [cm]: 81.27831766586635
#
# ==================================================
# Cut value: 3.0
# ==================================================
# Mean number of removed tracks: 0.791981597108117
# x-projection PV resolution [cm]: 72.01733950027311
# y-projection PV resolution [cm]: 72.1845483751742
# z-projection PV resolution [cm]: 82.28464249743647
#
# ==================================================
# Cut value: 2.0
# ==================================================
# Mean number of removed tracks: 1.3267452232289565
# x-projection PV resolution [cm]: 75.89001542006953
# y-projection PV resolution [cm]: 75.51570949661422
# z-projection PV resolution [cm]: 85.79835555872747
# Best x at cut: 5.0
# Best y at cut: 7.0
# Best z at cut: 5.0

# %% [markdown]
# ## Cut properties

# %%
from analysis_scripts.draw_scripts import hist_plot


fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

hist_plot(
    data=df[df['max_chi2_cut'] == 6.0],
    distr_name='tracks_per_vertex',
    ax=axes[0][0],
    bins=40
)

hist_plot(
    data=df[df['max_chi2_cut'] == 6.0],
    distr_name='num_removed_tracks',
    ax=axes[0][1],
    bins=40
)

hist_plot(
    data=df[df['max_chi2_cut'] == 6.0],
    distr_name='chi2_PV',
    ax=axes[1][0],
    bins=40
)


hist_plot(
    data=df[df['max_chi2_cut'] == 6.0],
    distr_name='chi2_per_ndf_PV',
    ax=axes[1][1],
    bins=40
)

plt.tight_layout()

# %% [markdown]
# ## Resolutions

# %% [markdown]
# ### x-projection (cut = 6)

# %%
from analysis_scripts.fit_scripts import fit_distr_double_gauss


cut = 6.

distr_name = 'PV_diff_ES_x'

PV_diff_x = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_x']

sig_PV_df_sel = PV_diff_x[abs(PV_diff_x) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (x projection) Extra Selection',
    x_label='PV resolution (x projection) Extra Selection [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

# plt.savefig(f'../plots/{distr_name}_Sig.pdf')
# Out:
# Method: Nelder-Mead
# ****************************************************************************************************
# New best method: Nelder-Mead, success: True
# ****************************************************************************************************
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='Powell'
# ============================================================
# Optimization result:
# Success: True
# Message: Optimization terminated successfully.
# Number of iterations: 19
# Final objective value: 42.072769
# Chi-squared: 42.07
# Reduced chi-squared: 1.275
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 610.8003 +- 42.9449
#          mu = 0.000301 +- 0.000096
#          sigma = 0.008760 +- 0.000226
# Gauss 2: A = 1739.0129 +- 42.1884
#          mu = -0.000030 +- 0.000047
#          sigma = 0.003902 +- 0.000082
# Constant: C = 13.8029 +- 1.7999
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: 0.000056 +- 0.000043
# Effective Sigma: 0.005587 +- 0.000128
# ============================================================

# %% [markdown]
# ### y-projection (cut = 6)

# %%
from analysis_scripts.fit_scripts import fit_distr_double_gauss


cut = 6.

distr_name = 'PV_diff_ES_y'
PV_diff_x = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_y']

sig_PV_df_sel = PV_diff_x[abs(PV_diff_x) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (y projection) Extra Selection',
    x_label='PV resolution (y projection) Extra Selection [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

# plt.savefig(f'../plots/{distr_name}_Sig.pdf')
# Out:
# Method: Nelder-Mead
# ****************************************************************************************************
# New best method: Nelder-Mead, success: True
# ****************************************************************************************************
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='Powell'
# ============================================================
# Optimization result:
# Success: True
# Message: Optimization terminated successfully.
# Number of iterations: 21
# Final objective value: 48.784770
# Chi-squared: 48.78
# Reduced chi-squared: 1.478
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 548.0241 +- 52.3898
#          mu = 0.000060 +- 0.000114
#          sigma = 0.008792 +- 0.000307
# Gauss 2: A = 1800.8965 +- 50.2396
#          mu = 0.000019 +- 0.000049
#          sigma = 0.004014 +- 0.000093
# Constant: C = 18.7713 +- 2.2133
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: 0.000029 +- 0.000046
# Effective Sigma: 0.005512 +- 0.000160
# ============================================================

# %% [markdown]
# ### z-projection (cut = 6)

# %%
from analysis_scripts.fit_scripts import fit_distr_double_gauss


cut = 6.

distr_name = 'PV_diff_ES_z'
PV_diff_x = df.loc[df['max_chi2_cut'] == cut, 'PV_diff_ES_z']

sig_PV_df_sel = PV_diff_x[abs(PV_diff_x) < 0.03].copy()

methods = ['Nelder-Mead', 'Powell', 'CG', 'BFGS', 'Newton-CG', 'L-BFGS-B',
           'TNC', 'COBYLA', 'COBYQA', 'SLSQP', 'trust-constr', 'dogleg',
           'trust-ncg', 'trust-exact', 'trust-krylov']

min_loss = 1e6
best_method = None

for method in methods:

    print(f'Method: {method}')

    if method in ('SLSQP'):
        print(f'Skip method: {method}')
        continue

    with redirect_stdout(io.StringIO()), redirect_stderr(io.StringIO()):
        try:
            fit_res = fit_distr_double_gauss(
                distr=sig_PV_df_sel,
                title=distr_name,
                x_label=distr_name + ' [cm]',
                optimize_method=method,
                plot=False,
                bins=40,
                max_iter=1000
            )
        except:
            print(f'Skip method: {method}')
            continue
    
    result = fit_res['result']
    
    if result['success'] and result['fun'] < min_loss:
        print('*'*100)
        print(f'New best method: {method}, success: {result['success']}')
        print('*'*100)
        best_method = method
        min_loss = result['fun']
    
print('*' * 80)
print('*' * 80)
print('*' * 80)
print(f'{best_method=}')

if best_method is None:
    raise ValueError('No successful fit')

result = fit_distr_double_gauss(
    distr=sig_PV_df_sel,
    title='PV resolution (z projection) Extra Selection',
    x_label='PV resolution (z projection) Extra Selection [cm]',
    optimize_method=best_method,
    plot=True,
    bins=40,
    max_iter=1000
)

# plt.savefig(f'../plots/{distr_name}_Sig.pdf')
# Out:
# Method: Nelder-Mead
# ****************************************************************************************************
# New best method: Nelder-Mead, success: True
# ****************************************************************************************************
# Method: Powell
# ****************************************************************************************************
# New best method: Powell, success: True
# ****************************************************************************************************
# Method: CG
# Method: BFGS
# Method: Newton-CG
# Method: L-BFGS-B
# Method: TNC
# Method: COBYLA
# Method: COBYQA
# Method: SLSQP
# Skip method: SLSQP
# Method: trust-constr
# Method: dogleg
# Method: trust-ncg
# Method: trust-exact
# Method: trust-krylov
# ********************************************************************************
# ********************************************************************************
# ********************************************************************************
# best_method='Powell'
# ============================================================
# Optimization result:
# Success: True
# Message: Optimization terminated successfully.
# Number of iterations: 23
# Final objective value: 50.038520
# Chi-squared: 50.04
# Reduced chi-squared: 1.516
# ------------------------------------------------------------
# Fit parameters with errors:
# Gauss 1: A = 584.5463 +- 56.7839
#          mu = 0.000225 +- 0.000120
#          sigma = 0.009344 +- 0.000364
# Gauss 2: A = 1416.1103 +- 55.1723
#          mu = -0.000053 +- 0.000064
#          sigma = 0.004281 +- 0.000127
# Constant: C = 31.5949 +- 3.4142
# ------------------------------------------------------------
# Derived quantities:
# Effective Mean: 0.000028 +- 0.000058
# Effective Sigma: 0.006203 +- 0.000210
# ============================================================

# %% [markdown]
# # PV Reconstruction Analysis Notes
#
# ## Dataset Overview
# - **Total size:** ~21,301 primary vertices (PVs)
# - **Creation script:** `pv_dataset_27.cpp`
#
# ## Key Points
#
# ### 1. Resolution Dependence on Track Selection
# Resolution significantly depends on the minimum number of tracks available for PV reconstruction. The current selection requires at least 4 tracks:
#
#
# ```cpp
# if (KFParticles_PV.size() < 4) continue;
# ```
#
# * Current PV acceptance: 0.737
#
# * Similar improvement can be achieved by requiring a minimum number of tracks per vertex after the re-fit procedure, which improves resolution while rejecting some PVs.
#
# ### 2. Unexplored Selection Factors
# The following track selection criteria remain unexplored in this analysis:
# ```cpp
# if (trkPos.Perp() > 0.3 || (PV_pos_prefit - trkPos).Mag() > 0.4) continue;
# ```
#
# ### 3. Re-fit Implementation Notes
# * Two PV re-fit implementations have been explored (both in `pv_dataset_27.cpp`)
# * PV acceptance is independent of re-fit variant unless restrictions are applied to `tracks_per_vertex` after re-fitting
#
# ## Performance Summary
# |          | no re-fit | Var I | Var II |
# |----------|---------------|---|--------|
# |  **x**   |   57.86   | 54.06 | 55.87  |
# |  **y**   |   57.74   | 54.05 | 55.12  |
# |  **z**   |   64.69   | 59.87 | 62.03  |
#
# ## Conclusions:
#
# 1. Use var-I re-fit strategy in main analysis;
# 2. Set optimal_cut to 5;
# 3. The possibility of the cut on min number of after re-fit selected PV tracks are studied in `Lc_decay_length_analysis.ipynb`;
